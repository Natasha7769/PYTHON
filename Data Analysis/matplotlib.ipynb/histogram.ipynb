# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x = np.random.randint(10,60,50)
print(x)
# Out:
# [13 31 56 13 29 32 39 23 37 46 54 36 44 25 57 57 53 45 36 33 30 47 25 53
#  46 47 30 16 22 41 46 35 43 11 34 39 35 33 58 31 22 21 32 29 42 28 54 14
#  37 29]

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
plt.hist(no,color='b',edgecolor='r')
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
l=[10,20,30,40,50,60]
plt.hist(no,color='b',bins=l,edgecolor='r')
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
l=[10,20,30,40,50,60]
plt.hist(no,color='b',edgecolor='r',cumulative=-1)
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
plt.hist(no,color='b',edgecolor='r',bottom=20)
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
plt.hist(no,color='b',bins=l,edgecolor='r',align='left')
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
l=[10,20,30,40,50,60]
plt.hist(no,color='b',bins=l,edgecolor='r',align='mid')
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
l=[10,20,30,40,50,60]
plt.hist(no,color='b',bins=l,edgecolor='r',histtype='step')
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
l=[10,20,30,40,50,60]
plt.hist(no,color='b',bins=l,edgecolor='r',orientation= 'horizontal')  #vertical 
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
l=[10,20,30,40,50,60]
plt.hist(no,color='b',bins=l,edgecolor='r',rwidth=0.8)
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
l=[10,20,30,40,50,60]
plt.hist(no,color='b',bins=l,edgecolor='r',log=True)
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')
plt.show()

# %%
no=[13 ,31 ,56, 13, 29, 32, 39, 23, 37, 46, 54, 36, 44, 25, 57, 57, 53, 45, 36, 33, 30, 47, 25, 53,
 46, 47, 30, 16, 22, 41, 46, 35, 43, 11, 34, 39, 35, 33, 58, 31, 22, 21, 32, 29, 42, 28, 54, 14,
 37, 29]
l=[10,20,30,40,50,60]
plt.hist(no,color='b',bins=l,edgecolor='r',label='python')
plt.title('data')
plt.xlabel('python')
plt.ylabel('No')

plt.axvline(45,color='g',label='line')
plt.legend()
plt.grid()
plt.show()
